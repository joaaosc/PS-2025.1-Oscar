# %%
# ipynb para analisarmos gráficos de cada coluna

# %%
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append(os.path.abspath("../src"))

import AnaliseExploratoria_functions as AnaliseExploratoria_functions
from AnaliseExploratoria_functions import histogram_and_stats, evaluate_distribution

current_path = os.path.dirname(os.getcwd())
csv_path = (current_path + '/Data/campeonatos_futebol_sem_outliers.csv')

# %%
df = pd.read_csv(csv_path)
df.head()
# Out:
#    Chutes a gol 1  Chutes a gol 2  Impedimentos 1  Impedimentos 2  \
# 0             8.0             0.0             6.0             3.0
# 1             0.0             2.0             0.0             2.0
# 2             4.0             5.0             1.0             5.0
# 3             4.0             7.0             8.0             1.0
# 4             3.0             1.0             1.0             3.0
#
#    Escanteios 1  Escanteios 2  Chutes fora 1  Chutes fora 2  Faltas 1  \
# 0           7.0           1.0            6.0            1.0       8.0
# 1           0.0           4.0            3.0            4.0      19.0
# 2           8.0          11.0            2.0            5.0      13.0
# 3           6.0           5.0            4.0            7.0       4.0
# 4           5.0           4.0            2.0            2.0      12.0
#
#    Faltas 2  ...  Tratamentos 1  Tratamentos 2  Substituições 1  \
# 0      14.0  ...            NaN            NaN              3.0
# ...

# %%
# plot dos gráficos para todas as variáveis numéricas

for col in df.select_dtypes(include="number").columns:
    AnaliseExploratoria_functions.evaluate_distribution(df, col, show_boxplot=True)
# Out:
# Coluna: Chutes a gol 1
# Skewness: 0.779
# Kurtosis (excesso): 0.897
# Coluna: Chutes a gol 2
# Skewness: 0.866
# Kurtosis (excesso): 1.547
# Coluna: Impedimentos 1
# Skewness: 1.182
# Kurtosis (excesso): 2.536
# Coluna: Impedimentos 2
# Skewness: 1.199
# Kurtosis (excesso): 2.206
# Coluna: Escanteios 1
# Skewness: 0.685
# Kurtosis (excesso): 0.606
# Coluna: Escanteios 2
# Skewness: 0.745
# Kurtosis (excesso): 0.779
# Coluna: Chutes fora 1
# Skewness: 0.801
# Kurtosis (excesso): 0.962
# Coluna: Chutes fora 2
# Skewness: 99.863
# Kurtosis (excesso): 13585.115
# Coluna: Faltas 1
# Skewness: 0.333
# Kurtosis (excesso): 0.274
# Coluna: Faltas 2
# Skewness: 0.322
# Kurtosis (excesso): 0.252
# Coluna: Cartões amarelos 1
# Skewness: 0.645
# Kurtosis (excesso): 0.315
# Coluna: Cartões amarelos 2
# Skewness: 0.565
# Kurtosis (excesso): 0.258
# Coluna: Cartões vermelhos 1
# Skewness: 4.637
# Kurtosis (excesso): 22.245
# Coluna: Cartões vermelhos 2
# Skewness: 4.438
# ...
