// %%
Console.WriteLine("Essa é uma linha em C#")
// Out:
// <div>
//     <div id='dotnet-interactive-this-cell-544.Microsoft.DotNet.Interactive.Http.HttpPort' style='display: none'>
//         The below script needs to be able to find the current output cell; this is an easy method to get it.
//     </div>
//     <script type='text/javascript'>
// async function probeAddresses(probingAddresses) {
//     function timeout(ms, promise) {
//         return new Promise(function (resolve, reject) {
//             setTimeout(function () {
//                 reject(new Error('timeout'))
//             }, ms)
//             promise.then(resolve, reject)
//         })
//     }
//
//     if (Array.isArray(probingAddresses)) {
//         for (let i = 0; i < probingAddresses.length; i++) {
//
//             let rootUrl = probingAddresses[i];
//
//             if (!rootUrl.endsWith('/')) {
//                 rootUrl = `${rootUrl}/`;
//             }
//
//             try {
// ...

// %%
Console.WriteLine("Com C#, talvez seja possível usar os métodos do ML.NET na hora de construir o modelo.")
// Out:
// Com C#, talvez seja possível usar os métodos do ML.NET na hora de construir o modelo.

// %%
print("agora em Python!")
// Out:
// agora em Python!
